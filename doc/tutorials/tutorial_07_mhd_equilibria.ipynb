# %% [markdown]
# # 7 - MHD equilibria
#
# Tutorial in the making!

# %%
from struphy.fields_background.mhd_equil.equils import EQDSKequilibrium, GVECequilibrium
from struphy.geometry.domains import Tokamak

# %%
# mhd_equil = EQDSKequilibrium()
# mhd_equil.domain = Tokamak(equilibrium=mhd_equil)
# mhd_equil.show()

# %%
# # choose which equilibrium to plot
# mhd_equil = GVECequilibrium()
# mhd_equil.show() # vtk files are generated in this step too
