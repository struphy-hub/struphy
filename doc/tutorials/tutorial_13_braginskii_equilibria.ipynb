# %% [markdown]
# # 12 - Braginskii equilibria

# %%
from struphy.fields_background.braginskii_equil import equils
from struphy.geometry import domains

# %% [markdown]
# ## Homogeneous slab ITG

# %%
eq = equils.HomogenSlabITG(Lx=2.)
eq.domain = domains.Cuboid(l1=0., r1=2.)
eq.show()
