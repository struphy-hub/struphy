# %% [markdown]
# $$
# % transferring macros:
# \let\eps\varepsilon
# \let\wt\widetilde
# \let\tn\mathrm
# \let\vphi\varphi
# \let\pa\partial
# \let\para\parallel
# \let\wh\widehat
# \let\sl\shoveleft
# % defining new macros:
# \def\be{\begin{equation} \mskip 1cm}
# \def\ee{\end{equation}}
# \def\ba{\begin{align} \mskip 1cm}
# \def\ea{\end{align}}
# \def\RR{{\mathbb R}}
# \def\DD{{\mathbb D}}
# \def\GG{{\mathbb G}}
# \def\CC{{\mathbb C}}
# \def\MM{{\mathbb M}}
# \def\JJ{{\mathbb J}}
# \def\WW{{\mathbb W}}
# \def\HH{{\mathbb H}}
# \def\SS{{\mathbb S}}
# \def\QQ{{\mathbb Q}}
# \def\Bb{{\mathbf B}}
# \def\Eb{{\mathbf E}}
# \def\Ub{{\mathbf U}}
# \def\Ab{{\mathbf A}}
# \def\Jb{{\mathbf J}}
# \def\xb{{\mathbf x}}
# \def\eb{{\mathbf e}}
# \def\nb{{\mathbf n}}
# \def\wb{{\mathbf w}}
# \def\ub{{\mathbf u}}
# \def\bb{{\mathbf b}}
# \def\rb{{\mathbf r}}
# \def\jb{{\mathbf j}}
# \def\kb{{\mathbf k}}
# \def\Fb{{\mathbf F}}
# \def\Cb{{\mathbf C}}
# \def\Yb{{\mathbf Y}}
# \def\Mb{{\mathbf M}}
# \def\grad{\tn{grad}}
# \def\curl{\tn{curl}}
# \def\unit{\mathbb 1}
# \def\div{\tn{div}}
# \def\Im{\tn{Im}}
# \newcommand{\fhD}{f_\tn{h}^\tn{D}}
# \newcommand{\whD}{w_\tn{h}^\tn{D}}
# \newcommand{\nhD}{n_\tn{h}^\tn{D}}
# \newcommand{\jhD}{\jb_\tn{h}^\tn{D}}
# % defining new commands:
# \newcommand{\abs}[1]{\lvert#1\rvert}
# \newcommand{\bold}[1]{{\boldsymbol #1}}
# \newcommand{\pder}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\dt}[1]{\frac{\mathrm d #1}{\mathrm dt}}
# \newcommand{\ds}[1]{\frac{\mathrm d #1}{\mathrm ds}}
# \def\dd{\mathrm{d}}
# $$

# %% [markdown]
# # MHD-drift-kinetic hybrid models
#
# This is a collection of hybrid models we will consider during the thesis. The notebook includes:
#
# 1. Geometric structures (Lagrangians, Poisson brackets) on the continuous level.
# 2. Dispersion relations.
# 3. 2D and 3D de Rham complexes and corresponding construction of basis functions (splines, Lagrange).
#
# References are:
#
# * _Stefan's notes_ on hybrid modeling in current-coupling scheme (CCS).
# * J. Burby, C. Tronci, _Variational approach to low-frequency kinetic-MHD in the current coupling scheme_, PPCF 2017.
#
#
# # 1. Models and dispersion relations
#
# ## Standard MHD
#
# In standard MHD the electric field takes the simple form
#
# $$
# \be \label{sub1:E}
#  \Eb = -\Ub \times \Bb\,,
# \ee
# $$
#
# where $\Ub$ stands for the plasma bulk velocity. The standard, compressible MHD equations read
#
# $$
# \begin{align}
#  &\pder{\tau}{t} + \nabla \cdot (\tau \Ub) = 0\,,
#  \\[2mm]
#  &\pder{\Ub}{t} + \Ub \cdot \nabla \Ub + \frac{\nabla p}{\tau}
#   =  \frac{1}{\mu_0}\frac{\nabla \times
# \Bb }{\tau} \times\Bb   \,,
#  \\[2mm]
#  &\pder{p}{t} +  \Ub \cdot \nabla p + \gamma\, p\, \nabla \cdot \Ub  = 0\,,
#  \\[2mm]
#  & \pder{\Bb}{t} = \nabla \times (\Ub \times \Bb)\,.
# \end{align}
# $$
#
# Here, $\tau$ denotes the plasma mass, $p$ is the plasma pressure and $\gamma = 5/3$ is the specific heat ratio of an ideal gas in 3D.

# %% [markdown]
# ### Geometric structure

# %% [markdown]
# ### Linear MHD and dispersion relation
#
# Linearized MHD equations are obtained by keeping only the first
# order terms in an expansion of the solution around the homogeneous equilibrium
#
# $$
# \be \label{equil:hom}
#  \tau_0 = const. \,,\qquad \Ub_0 = 0\,,\qquad p_0 = const.\,,\qquad \Bb_0 = B_0\,\eb_z\,.
# \ee
# $$
#
# Writing $\tau = \tau_0 + \tau_1$ and relabeling $\tau_1 \to \tau$ after linearization
# yields the system
#
# $$
# \begin{align}
#  &\pder{\tau}{t} + \tau_0\nabla \cdot \Ub = 0\,,
#  \\[2mm]
#  &\pder{\Ub}{t} + \frac{\nabla p}{\tau_0} =  \frac{B_0}{\tau_0\mu_0}\, (\nabla \times
# \Bb ) \times \eb_z   \,,  \label{lin1:U}
#  \\[2mm]
#  &\pder{p}{t} + \gamma\, p_0\, \nabla \cdot \Ub  = 0\,,
#  \\[2mm]
#  & \pder{\Bb}{t} = B_0\,\nabla \times (\Ub \times \eb_z)\,.
# \end{align}
# $$
#
# We are interested in waves propagating in the direction of the magnetic field, hence with wave
# vector $\kb = k_\para\eb_z$. Writing the unknowns as $\wb = (\tau,\Ub,p,\Bb)^\top \in \RR^8$, we
# insert the ansatz $\wb(z,t) = \wh \wb\, e^{i (k_\para z - \omega t)}$ with $\wh
# \wb \in\RR^8$ constant to obtain the eigenvalue problem
#
# $$
# \be \label{eig1}
#  - \omega\,\wb + \Ab \cdot \wb = 0\,,
# \ee
# $$
#
# where the matrix $\Ab \in \RR^{8\times 8}$ can be deduced from
#
# $$
# \begin{align}
#  &-\omega\,\tau + \tau_0\, k_\para U_\para = 0\,,
#  \\[2mm]
#  &-\omega\,\Ub + \frac{1}{\tau_0} k_\para\, p\,\eb_z - \frac{B_0}{\tau_0\mu_0}\,k_\para\Bb_\perp =
# 0   \,,
#  \\[2mm]
#  &- \omega\,p + \gamma\, p_0\, k_\para U_\para  = 0\,,
#  \\[3mm]
#  & -\omega\,\Bb - B_0\,k_\para\Ub_\perp = 0 \,,
# \end{align}
# $$
#
# and we used the notation $U_\para = \Ub \cdot \eb_z$ and $\Ub_\perp = \eb_z \times \Ub \times
# \eb_z = (U_x,U_y,0)^\top$. Solving \eqref{eig1} is straightforward: from the above we obtain
#
# $$
# \be \label{lin1sol:a}
#  \tau = \frac{\tau_0}{\omega}\, k_\para U_\para \,,\qquad  p = \frac{\gamma\, p_0}{\omega}\,
# k_\para U_\para  \,,\qquad \Bb = \Bb_\perp = - \frac{B_0}{\omega}\,k_\para\Ub_\perp \,,
# \ee
# $$
#
# which inserted into the momentum equation leads to
#
# $$
# \be \label{lin1sol:b}
#  \omega^2\,\Ub - \frac{\gamma\,p_0}{\tau_0}\, k_\para^2\, U_\para\,\eb_z -
# \frac{B_0^2}{\tau_0\mu_0}\,k_\para^2\,\Ub_\perp = 0\,.
# \ee
# $$
#
# The two relevant velocities are the sound speed $v_s$ and the Alfv\'en velocity $v_A$,
#
# $$
# \be
#  v_\tn{s} = \sqrt{\frac{\gamma\,p_0}{\tau_0}}\,,\qquad v_\tn{A} =
# \sqrt{\frac{B_0^2}{\tau_0\mu_0}}\,,
# \ee
# $$
#
# such that \eqref{lin1sol:b} reads
#
# $$
# \be
#  \begin{pmatrix}
#   \omega^2 - v_\tn{A}^2\,k_\para^2 & 0 & 0 \\
#   0 & \omega^2 - v_\tn{A}^2\,k_\para^2 & 0 \\
#   0 & 0 & \omega^2 - v_\tn{s}^2 \,k_\para^2
#  \end{pmatrix}
#  \begin{pmatrix}
#   U_x \\ U_y \\ U_\para
#  \end{pmatrix}
#  = 0\,.
# \ee
# $$
#
# Hence, there are two kinds of eigenmodes:
#
# 1. Sound waves: $\omega = \pm c_\tn{s} k_\para$. In this case $\Ub_\perp = 0$ and thus there
# is no perturbation of the magnetic field due to \eqref{lin1sol:a}.
#
# 2. Shear Alfv\'en waves: $\omega = \pm v_\tn{A} k_\para$. In this case $U_\para = 0$, the
# magnetic wave is transversal and there is no perturbation of the density and the
# pressure due to \eqref{lin1sol:a}.

# %% [markdown]
# ## MHD-drift-kinetic current coupling
#
# Here, standard MHD is coupled to the drift kinetic equation for the hot ions:
#
# $$
# \begin{align}
#  &\pder{\tau}{t} + \nabla \cdot (\tau \Ub) = 0\,,
#  \\[3mm]
#  &\pder{\Ub}{t} + \Ub \cdot \nabla \Ub + \frac{\nabla p}{\tau}
#   =   \frac{1}{\mu_0}\frac{\nabla \times
# \Bb }{\tau} \times\Bb + \frac{(q_\tn{h}\nhD\,\Ub - \jhD )}{\tau} \times\Bb
# \,,
#  \\[3mm]
#  &\pder{p}{t} +  \Ub \cdot \nabla p + \gamma\, p\, \nabla \cdot \Ub  = 0\,,
#  \\[3mm]
#  & \pder{\Bb}{t} = \nabla \times (\Ub \times \Bb)\,,
#  \\[3mm]
#  & \pder{\fhD}{t} + \ub_\tn{g} \cdot \nabla \fhD + E_\tn{g}\,
# \pder{\fhD}{v_\para} = 0\,,
# \end{align}
# $$
#
# where $\fhD = \fhD(t,\rb,v_\para,\wh\mu)$ is the guiding-center (GC) distribution, $\rb$ denotes the GC position, $v_\para$ the parallel GC velocity and $\wh\mu$ is a constant of the motion (generalized magnetic moment). Moreover,
#
# $$
# \be \label{sub3:ugEg}
#  \ub_\tn{g} =  v_\para\,\frac{\Bb^*}{B^*_\para} +
# \frac{\Eb^* \times
# \bb}{B^*_\para} \,,\qquad E_\tn{g} = \frac{q_\tn{h}}{m_\tn{h}} \frac{\Eb^* \cdot
# \Bb^*}{B^*_\para} \,,
# \ee
# $$
#
# where $q_\tn{h}$ and $m_\tn{h}$ stand for the hot particle's charge and mass, respectively, and
#
# $$
# \begin{align}
#  \Bb^* &= \Bb + \frac{m_\tn{h}}{q_\tn{h}} v_\para\nabla \times \bb\,,
#  \\[2mm]
#  \Eb^* &= -\Ub \times \Bb - \frac{m_\tn{h}}{q_\tn{h}} \wh \mu \nabla B - \frac{m_\tn{h}}{q_\tn{h}} v_\para  \pder{\bb}{t}\,,
#  \\[2mm]
#  \nhD &= \int \fhD\,B^*_\para\,\tn dv_\para\tn d\wh\mu\,,
#  \\[2mm]
#  \jhD &= q_\tn{h}
# \int_{\wh\mu}\ub_\tn{g}\,
# \fhD\,B^*_\para\,\tn dv_\para + \nabla \times \Mb\,,
#  \\[2mm]
#  \Mb &= - m_\tn{h}\int\bigg[ \wh\mu\,\bb -
# \frac{v_\para}{B}\,\ub_{\tn{g},\perp} \bigg]\,\fhD\,B^*_\para\,\tn
# dv_\para \tn d\wh\mu\,,  \label{sub3:M}
# \end{align}
# $$
#
# with $B^*_\para = \Bb^* \cdot \bb$.

# %% [markdown]
# ### Geometric structure of the full model

# %% [markdown]
# ### Linear MHD part
#
# Let us consider a coupling of the linear MHD equations (from section 1.1) with the full drift-kinetic equation:
#
# $$
# \begin{align}
#  &\pder{\tau}{t} + \tau_0\nabla \cdot \Ub = 0\,,
#  \\[2mm]
#  &\pder{\Ub}{t} + \frac{\nabla p}{\tau_0} =  \frac{B_0}{\tau_0\mu_0}\, (\nabla \times
# \Bb ) \times \eb_z + \frac{B_0}{\tau_0}(q_\tn{h}(\nhD)_0\,\Ub - \jhD ) \times \eb_z \color{red}{+ \tn{nonlinear\ terms\ for\ structure\ !}}\,,  \label{lin1:U}
#  \\[2mm]
#  &\pder{p}{t} + \gamma\, p_0\, \nabla \cdot \Ub  = 0\,,
#  \\[2mm]
#  & \pder{\Bb}{t} = B_0\,\nabla \times (\Ub \times \eb_z)\,.
#  \\[3mm]
#  & \pder{\fhD}{t} + \ub_\tn{g} \cdot \nabla \fhD + E_\tn{g}\,
# \pder{\fhD}{v_\para} = 0\,,
# \end{align}
# $$

# %% [markdown]
# ### Geometric structure with linear MHD part

# %% [markdown]
# ### Dispersion relation

# %% [markdown]
# We linearize the MHD equations in the same way as before. Moreover, we take a DK equilibrium distribution of the form
#
# $$
# \begin{align}
#  &f_{\tn{h}0}^\tn{D}=\left(\frac{m_\tn{h}}{2\pi}\right)^{3/2}\frac{n_{\tn{h}0}}{ \sqrt{T_{\tn{h}\parallel}}T_{\tn{h}\perp}}\exp\left(-\frac{m_\tn{h}q_\parallel^2}{2T_{\tn{h}\parallel}}\right)\exp\left(-\frac{m_\tn{h}\hat{\mu}B_0}{T_{\tn{h}\perp}}\right)\,,
# \end{align}
# $$
#
# such that with $\int_{\hat{\mu}}\ldots\tn{d}q_\parallel=2\pi\int_0^\infty\int_{-\infty}^\infty\ldots\tn{d}q_\parallel\tn{d}\hat{\mu}$ we have
#
# $$
# \begin{align}
#  &\int_{\hat{\mu}}\begin{pmatrix}1\\q_\parallel\\q_\parallel^2\\q_\parallel^3\end{pmatrix}f_{\tn{h}0}^\tn{D}B_0\,\tn{d}q_\parallel=\begin{pmatrix}n_{\tn{h}0}\\0\\n_{\tn{h}0}T_{\tn{h}\parallel}/m_\tn{h}\\0\end{pmatrix}\,,\qquad\int_{\hat{\mu}}\hat{\mu}f_{\tn{h}0}^\tn{D}B_0\,\tn{d}q_\parallel=\frac{n_{\tn{h}0}T_{\tn{h}\perp}}{m_\tn{h}B_0}\,.
# \end{align}
# $$
#
# Let us start with the linearized DK equation:
#
# $$
# \begin{align}
#  &\frac{\partial f_{\tn{h}1}^\tn{D}}{\partial t}+\ub_{\tn{g}0}\cdot\nabla f_{\tn{h}1}^\tn{D}=-E_{\tn{g}1}\frac{\partial f_{\tn{h}0}^\tn{D}}{\partial q_\parallel}\,.\\
#  \Leftrightarrow\quad&\frac{\partial f_{\tn{h}1}^\tn{D}}{\partial t}+q_\parallel\eb_z\cdot\nabla f_{\tn{h}1}^\tn{D}=0\,,
# \end{align}
# $$
#
# since $\ub_{\tn{g}0}=q_\parallel\eb_z$ and $E_{\tn{g}1}=0$. This equation simply describes an advection in $z-$ direction with the constant velocity $q_\parallel$. Thus, the solution is given by
#
# $$
# \begin{align}
#  &f_{\tn{h}1}^\tn{D}(x,y,z,q_\parallel,\hat{\mu},t)=f_{\tn{h}1}^\tn{D}(x,y,z-q_\parallel t,q_\parallel,\hat{\mu},t=0):=f_{\tn{h}1}^\tn{D0}(x,y,z-q_\parallel t,q_\parallel,\hat{\mu})\,.
# \end{align}
# $$
#
# For the computation of the perturbed current density $\jb_\tn{h1}^\tn{D}$, we need the linearized gyro-center velocity
#
# $$
# \begin{align}
#  &\ub_\tn{g1}=\frac{q_\parallel}{B_0}\left(\Bb_1+\frac{q_\parallel}{a_\tn{h}B_0}\nabla\times\Bb_1\right)+\Ub_{1\perp}-\frac{q_\parallel}{a_\tn{h}B_0^2}\frac{\pa\Bb_1}{\pa t}\times\eb_z\,,\\
#  \Rightarrow\quad&\int_\hat{\mu}\ub_\tn{g1}f_{\tn{h}0}^\tn{D}B_0\,\tn{d}q_\parallel=\frac{n_{\tn{h}0}T_{\tn{h}\parallel}}{a_\tn{h}B_0^2m_\tn{h}}\nabla\times\Bb_1+n_{\tn{h}0}\Ub_{1\perp}\,.
# \end{align}
# $$
#
# The perturbed current density $\jb_\tn{h1}^\tn{D}$ is given by
#
# $$
# \begin{align}
#  &\jb^\tn{D}_{\tn{h}1}=q_\tn{h}\int_{\hat{\mu}}(\ub_\tn{g0}f_{\tn{h}1}^\tn{D}+\ub_\tn{g1}f_{\tn{h}0}^\tn{D})B_0+\nabla\times\Mb_1=q_\tn{h}\eb_z\int_{\hat{\mu}}q_\parallel f_{\tn{h}1}^\tn{D0}B_0\,\tn{d}q_\parallel+\frac{q_\tn{h}n_{\tn{h}0}T_{\tn{h}\parallel}}{a_\tn{h}B_0^2m_\tn{h}}\nabla\times\Bb_1+q_\tn{h}n_{\tn{h}0}\Ub_{1\perp}+\nabla\times\Mb_1\,.
# \end{align}
# $$
#
# Hence, we get for the linearized magnetization
#
# $$
# \begin{align}
#  \Mb_1&=-m_\tn{h}\int_{\hat{\mu}}\hat{\mu}\Bb_1 f_{\tn{h}0}^\tn{D}\,\tn{d}q_\parallel-m_\tn{h}B_0\eb_z\int_{\hat{\mu}}\hat{\mu} f_{\tn{h}1}^\tn{D}\,\tn{d}q_\parallel+m_\tn{h}\int_{\hat{\mu}}\left(\frac{q_\parallel^3}{a_\tn{h}B_0^2}f_{\tn{h}0}^\tn{D}(\nabla\times\Bb_1)_\perp+q_\parallel f_{\tn{h}0}^\tn{D}\Ub_{1\perp}-\frac{q_\parallel^2}{a_\tn{h}B_0^2}f_{\tn{h}0}^\tn{D}\frac{\pa\Bb_1}{\pa t}\times\eb_z\right)\,\tn{d}q_\parallel\\
#  &=-\frac{n_{\tn{h}0}T_{\tn{h}\perp}}{B_0^2}\Bb_1-m_\tn{h}B_0\eb_z\int_{\hat{\mu}}\hat{\mu} f_{\tn{h}1}^\tn{D0}\,\tn{d}q_\parallel-\frac{n_{\tn{h}0}T_{\tn{h}\parallel}}{a_\tn{h}B_0^3}\frac{\pa\Bb_1}{\pa t}\times\eb_z\,.
# \end{align}
# $$
#
# This leads to the perturbed current density
#
# $$
# \begin{align}
#  &\jb_{\tn{h}1}^\tn{D}=q_\tn{h}\eb_z\int_{\hat{\mu}}q_\parallel f_{\tn{h}1}^\tn{D0}B_0\,\tn{d}q_\parallel+\frac{q_\tn{h}n_{\tn{h}0}T_{\tn{h}\parallel}}{a_\tn{h}B_0^2m_\tn{h}}\nabla\times\Bb_1+q_\tn{h}n_{\tn{h}0}\Ub_{1\perp}-\frac{n_{\tn{h}0}T_{\tn{h}\perp}}{B_0^2}\nabla\times\Bb_1-\frac{n_{\tn{h}0}T_{\tn{h}\parallel}}{a_\tn{h}B_0^3}\nabla\times\left(\frac{\pa\Bb_1}{\pa t}\times\eb_z\right)-m_\tn{h}B_0\int_{\hat{\mu}}\hat{\mu}(\nabla\times\eb_z f_{\tn{h}1}^\tn{D0})\,\tn{d}q_\parallel\,.
# \end{align}
# $$
#
# Let's assume a perturbed DK distribution function of the form $f_{\tn{h}1}^\tn{D}(z,q_\parallel,\hat{\mu},t)=\epsilon\cos(a(z-q_\parallel t))f_{\tn{h}0}^\tn{D}(q_\parallel,\hat{\mu})$ with $\epsilon\ll 1$.
#
# $$
# \begin{align}
#  &\Rightarrow\quad q_\tn{h}\eb_z\int_{\hat{\mu}}q_\parallel f_{\tn{h}1}^\tn{D0}B_0\,\tn{d}q_\parallel=q_\tn{h}B_0\eb_z\epsilon\int_{\hat{\mu}}q_\parallel \cos(a(z-q_\parallel t))f_{\tn{h}0}^\tn{D}(q_\parallel,\hat{\mu})\,\tn{d}q_\parallel=\eb_z\frac{q_\tn{h}n_\tn{h}T_{\tn{h}\parallel}at}{m_\tn{h}}\exp\left(-\frac{T_{\tn{h}\parallel}a^2t^2}{2m_\tn{h}}\right)\sin(az)\,,\\
#  &\Rightarrow\quad\jb_{\tn{h}1}^\tn{D}=\eb_z\frac{q_\tn{h}n_\tn{h}T_{\tn{h}\parallel}at}{m_\tn{h}}\exp\left(-\frac{T_{\tn{h}\parallel}a^2t^2}{2m_\tn{h}}\right)\sin(az)+\frac{q_\tn{h}n_{\tn{h}0}T_{\tn{h}\parallel}}{a_\tn{h}B_0^2m_\tn{h}}\nabla\times\Bb_1+q_\tn{h}n_{\tn{h}0}\Ub_{1\perp}-\frac{n_{\tn{h}0}T_{\tn{h}\perp}}{B_0^2}\nabla\times\Bb_1-\frac{n_{\tn{h}0}T_{\tn{h}\parallel}}{a_\tn{h}B_0^3}\nabla\times\left(\frac{\pa\Bb_1}{\pa t}\times\eb_z\right)
# \end{align}
# $$
#
# In the momentum balance equation for the bulk velocity $\Ub$, we need the term
#
# $$
# \begin{align}
#  &\frac{B_0}{\tau_0}\jb_\tn{h}^\tn{D}\times\eb_z=\frac{n_{\tn{h}0}}{\tau_0B_0}(T_{\tn{h}\parallel}-T_{\tn{h}\perp})(\nabla\times\Bb_1)\times\eb_z+\frac{B_0q_\tn{h}n_{\tn{h}0}}{\tau_0}\Ub_{1\perp}\times\eb_z-\frac{n_{\tn{h}0}T_{\tn{h}\parallel}}{\tau_0a_\tn{h}B_0^2}\left[\nabla\times\left(\frac{\pa\Bb_1}{\pa t}\times\eb_z\right)\right]\times\eb_z\,,
# \end{align}
# $$
#
# By looking for plane wave solutions $\sim\exp[i(k_\parallel z-\omega t)]$, this results in
#
# $$
# \begin{align}
#  &\frac{B_0}{\tau_0}\hat{\jb}_\tn{h}^\tn{D}\times\eb_z=\frac{ik_\parallel n_{\tn{h}0}}{\tau_0B_0}(T_{\tn{h}\parallel}-T_{\tn{h}\perp})\begin{pmatrix}\hat{B}_x\\ \hat{B}_y\\0\end{pmatrix}+\frac{B_0q_\tn{h}n_{\tn{h}0}}{\tau_0}\begin{pmatrix}\hat{U}_y\\ -\hat{U}_x\\0\end{pmatrix}-\frac{k_\parallel\omega n_{\tn{h}0}T_{\tn{h}\parallel}}{\tau_0a_\tn{h}B_0^2}\begin{pmatrix}\hat{B}_y\\ -\hat{B}_x\\0\end{pmatrix}\,,
# \end{align}
# $$
#
# which can be expressed only in terms of $\hat{\Ub}$ by using $\hat{\Bb}=-B_0k_\parallel\hat{\Ub}_\perp/\omega$ from Faraday's law:
#
# $$
# \begin{align}
#  &\frac{B_0}{\tau_0}\hat{\jb}_\tn{h}^\tn{D}\times\eb_z=-\frac{ik_\parallel^2 n_{\tn{h}0}}{\tau_0}(T_{\tn{h}\parallel}-T_{\tn{h}\perp})\begin{pmatrix}\hat{U}_x\\ \hat{U}_y\\0\end{pmatrix}+\frac{B_0q_\tn{h}n_{\tn{h}0}}{\tau_0}\begin{pmatrix}\hat{U}_y\\ -\hat{U}_x\\0\end{pmatrix}+\frac{k_\parallel^2n_{\tn{h}0}T_{\tn{h}\parallel}}{\tau_0a_\tn{h}B_0}\begin{pmatrix}\hat{U}_y\\ -\hat{U}_x\\0\end{pmatrix}\,.
# \end{align}
# $$
#
# This results in the the momentum balance equation
#
# $$
# \begin{align}
#  &-i\omega\begin{pmatrix}\hat{U}_x\\\hat{U}_y\\\hat{U}_\parallel\end{pmatrix}+i\frac{v_\tn{s}^2k_\parallel^2}{\omega}\begin{pmatrix}0\\0\\\hat{U}_\parallel\end{pmatrix}+i\frac{v_\tn{A}^2k_\parallel^2}{\omega}\begin{pmatrix}\hat{U}_x\\\hat{U}_y\\0\end{pmatrix}-\frac{ik_\parallel^2 n_{\tn{h}0}}{\tau_0}(T_{\tn{h}\parallel}-T_{\tn{h}\perp})\begin{pmatrix}\hat{U}_x\\ \hat{U}_y\\0\end{pmatrix}+\frac{B_0q_\tn{h}n_{\tn{h}0}}{\tau_0}\begin{pmatrix}\hat{U}_y\\ -\hat{U}_x\\0\end{pmatrix}+\frac{k_\parallel^2n_{\tn{h}0}T_{\tn{h}\parallel}}{\tau_0a_\tn{h}B_0}\begin{pmatrix}\hat{U}_y\\ -\hat{U}_x\\0\end{pmatrix}-\frac{B_0q_\tn{h}n_{\tn{h}0}}{\tau_0}\begin{pmatrix}\hat{U}_y\\-\hat{U}_x\\0\end{pmatrix}=0\,.
# \end{align}
# $$
#
# After multiplying by $i\omega$, replacing the temperatures by the thermal velocities $v_{\tn{th}\parallel}^2=2T_{\tn{h}\parallel}/m_\tn{h}$ respectively $v_{\tn{th}\perp}^2=2T_{\tn{h}\perp}/m_\tn{h}$ and using $m_\tn{i}=m_\tn{h}$, this is equivalent to
#
# $$
# \be
#  \begin{pmatrix}
#   \omega^2 - v_\tn{A}^2\,k_\para^2 + \nu_\tn{h}k_\para^2(v_{\tn{th}\parallel}^2-v_{\tn{th}\perp}^2)/2 & i\nu_\tn{h}\frac{\omega}{\Omega_{\tn{ci}}}k_\para^2v_{\tn{th}\parallel}^2/2 & 0 \\
#   -i\nu_\tn{h}\frac{\omega}{\Omega_{\tn{ci}}}k_\para^2v_{\tn{th}\parallel}^2/2 & \omega^2 - v_\tn{A}^2\,k_\para^2 + \nu_\tn{h}k_\para^2(v_{\tn{th}\parallel}^2-v_{\tn{th}\perp}^2)/2 & 0 \\
#   0 & 0 & \omega^2 - v_\tn{s}^2 \,k_\para^2
#  \end{pmatrix}
#  \begin{pmatrix}
#   \hat{U}_x \\ \hat{U}_y \\ \hat{U}_\para
#  \end{pmatrix}
#  = 0\,,
# \ee
# $$
#
# where $\nu_\tn{h}=n_{\tn{h}0}/n_0$ ($\tau_0=m_\tn{i}n_0$) is the ratio between the hot ion number density $n_{\tn{h}0}$ and the bulk density $n_0$ and $\Omega_\tn{ci}=q_\tn{i}B_0/m_\tn{i}$ is the ion cyclotron frequency. From this we end up with three kinds of eigenmodes. First, sound waves with $\omega=\pm v_\tn{s}k_\para$ which are unaffacted by the presence of energetic ions. Second, R-waves with
#
# $$
# \begin{align}
#  &D_R(k_\para,\omega)=\omega^2-v_\tn{A}^2k_\para^2+\nu_\tn{h}k_\para^2(v_{\tn{th}\parallel}^2-v_{\tn{th}\perp}^2)/2+\nu_\tn{h}\frac{\omega}{\Omega_{\tn{ci}}}k_\para^2v_{\tn{th}\parallel}^2/2=0\,,
# \end{align}
# $$
#
# and third, L-waves with
#
# $$
# \begin{align}
#  &D_L(k_\para,\omega)=\omega^2-v_\tn{A}^2k_\para^2+\nu_\tn{h}k_\para^2(v_{\tn{th}\parallel}^2-v_{\tn{th}\perp}^2)/2-\nu_\tn{h}\frac{\omega}{\Omega_{\tn{ci}}}k_\para^2v_{\tn{th}\parallel}^2/2=0\,.
# \end{align}
# $$
#
# which finally gives
#
# $$
# \begin{align}
#  &k_{\parallel,\tn{R/L}}=\pm\frac{\omega}{\sqrt{v_\tn{A}^2-\nu_\tn{h}(v_{\tn{th}\parallel}^2-v_{\tn{th}\perp}^2)/2-p_\tn{R/L}v_{\tn{th}\parallel}^2\omega/(2\Omega_\tn{ci})}}=\pm\frac{\omega}{v_\tn{A}\sqrt{1-\nu_\tn{h}\frac{v_{\tn{th}\parallel}^2}{2v_\tn{A}^2}(1-\frac{v_{\tn{th}\perp}^2}{v_{\tn{th}\parallel}^2}+p_\tn{R/L}\omega/\Omega_\tn{ci})}}\,,
# \end{align}
# $$
#
# where $p_\tn{R/L}=\pm1$ to account for the polarization.
#
# We can also solve for $\omega$ to arrive at
#
# $$
# \begin{align}
#  &2\omega_{\tn{R/L},\pm}(k_\parallel)=-p_{\tn{R/L}}\nu_\tn{h}k_\parallel^2v_{\tn{th}\parallel}^2/(2\Omega_\tn{ci})\pm\sqrt{\nu_\tn{h}^2k_\parallel^4v_{\tn{th}\parallel}^4/(4\Omega_\tn{ci}^2)+4v_\tn{A}^2k_\parallel^2-2\nu_\tn{h}k_\parallel^2(v_{\tn{th}\parallel}^2-v_{\tn{th}\perp}^2)}\,.
# \end{align}
# $$
#
# or in scaled variables $\omega^\prime=\omega/\Omega_\tn{ci}$, $v_{\tn{th}\parallel/\perp}^\prime=v_{\tn{th}\parallel/\perp}/v_\tn{A}$ and $k_\parallel^\prime=k_\parallel v_\tn{A}/\Omega_\tn{ci}$
#
# $$
# \begin{align}
#  &2\omega_{\tn{R/L},\pm}^\prime(k_\parallel^\prime)=-p_{\tn{R/L}}\nu_\tn{h}k_\parallel^{\prime2}v_{\tn{th}\parallel}^{\prime2}/2\pm\sqrt{\nu_\tn{h}^2k_\parallel^{\prime4}v_{\tn{th}\parallel}^{\prime4}/4+4k_\parallel^{\prime2}-2\nu_\tn{h}k_\parallel^{\prime2}(v_{\tn{th}\parallel}^{\prime2}-v_{\tn{th}\perp}^{\prime2})}\,.
# \end{align}
# $$
#
# In order to get wave growth or damping the square root must become negative. This means that
#
# $$
# \begin{align}
#  &k_\parallel^\prime<\frac{2}{v_{\tn{th}\parallel}^{\prime2}}\sqrt{\frac{2}{\nu_\tn{h}}(v_{\tn{th}\parallel}^{\prime2}-v_{\tn{th}\perp}^{\prime2})-4/\nu_\tn{h}^2}\,.
# \end{align}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

wci = 1
nuh = 0.2
vA = 1
vth_par  = 4*vA
vth_perp = 0.1*vA
vtilde = (vth_par**2 - vth_perp**2) 
sr = 2/nuh*vtilde - 4/nuh**2

def omega(k, pol, pm):
    return 1/2*(-pol*nuh*k**2*vth_par**2/(2*wci) + pm*np.sqrt(nuh**2*k**4*vth_par**4/(4*wci**2) + 4*vA**2*k**2 - 2*nuh*k**2*(vth_par**2 - vth_perp**2)))


k = np.linspace(0.0, 2, 200, dtype = complex)
w = np.zeros(200, dtype = complex)

pol = np.array([1, 1, -1, -1])
pm = np.array([1, -1, 1, -1])

for i in range(4):
    
    plt.figure()
    w = omega(k, pol[i], pm[i])


    plt.plot(np.real(k), np.real(w), label='Re($\omega$)')
    plt.plot(np.real(k), np.imag(w), label='Im($\omega$)')

    plt.xlabel('$k_\parallel$')
    plt.ylabel('$\omega$')

    plt.legend()
    
    if pol[i] == 1:
        plt.title('R-wave and ' + str(pm[i]))
        
    if pol[i] == -1:
        plt.title('L-wave and ' + str(pm[i]))

# %% [markdown]
# # 2. 3D de Rham complex

# %%
import spl.core.bsplines as bsplines
import numpy as np
import matplotlib.pyplot as plt
import Utilitis_HybridCode as utils
from scipy.integrate import fixed_quad
from scipy.integrate import nquad
from pyccel.epyccel import epyccel
import time

# %%
bc = False

Lx = 1
Ly = 1
Lz = 1

Nel_x = 3
Nel_y = 3
Nel_z = 3

dx = Lx/Nel_x
dy = Ly/Nel_y
dz = Lz/Nel_z

el_b_x = np.linspace(0, Lx, Nel_x+1)
el_b_y = np.linspace(0, Ly, Nel_y+1)
el_b_z = np.linspace(0, Lz, Nel_z+1)

px = 2
py = 2
pz = 2

Nbase_x = Nel_x + px 
Nbase_y = Nel_y + py 
Nbase_z = Nel_z + pz 

Nbase_x_0 = Nbase_x - 2 
Nbase_y_0 = Nbase_y - 2  
Nbase_z_0 = Nbase_z - 2  

Tx = bsplines.make_knots(el_b_x, px, bc)
Ty = bsplines.make_knots(el_b_y, py, bc)
Tz = bsplines.make_knots(el_b_z, pz, bc)

Dx = utils.Bspline(Tx, px-1)
Dy = utils.Bspline(Ty, py-1)
Dz = utils.Bspline(Tz, pz-1)


quad_xi_x_loc, quad_wi_x_loc = np.polynomial.legendre.leggauss(px+1)
quad_xi_y_loc, quad_wi_y_loc = np.polynomial.legendre.leggauss(py+1)
quad_xi_z_loc, quad_wi_z_loc = np.polynomial.legendre.leggauss(pz+1)

quad_xi_x, quad_wi_x = bsplines.quadrature_grid(el_b_x, quad_xi_x_loc, quad_wi_x_loc)
quad_xi_y, quad_wi_y = bsplines.quadrature_grid(el_b_y, quad_xi_y_loc, quad_wi_y_loc)
quad_xi_z, quad_wi_z = bsplines.quadrature_grid(el_b_z, quad_xi_z_loc, quad_wi_z_loc)

greville_x = bsplines.greville(Tx, px, bc)
greville_y = bsplines.greville(Ty, py, bc)
greville_z = bsplines.greville(Tz, pz, bc)

greville_x_0 = greville_x[1:Nbase_x-1]
greville_y_0 = greville_y[1:Nbase_y-1]
greville_z_0 = greville_z[1:Nbase_z-1]

col_x = np.transpose(bsplines.collocation_matrix(Tx, px, greville_x, bc))
col_y = np.transpose(bsplines.collocation_matrix(Ty, py, greville_y, bc))
col_z = np.transpose(bsplines.collocation_matrix(Tz, pz, greville_z, bc))

col_x_0 = col_x[1:Nbase_x-1, 1:Nbase_x-1]
col_y_0 = col_y[1:Nbase_y-1, 1:Nbase_y-1]
col_z_0 = col_z[1:Nbase_z-1, 1:Nbase_z-1]

# %%
# assemble discrete gradient matrix (V0 --> V1)
GRAD_x = np.zeros(((Nbase_x - 1)*Nbase_y_0*Nbase_z_0, Nbase_x_0*Nbase_y_0*Nbase_z_0))

for i1 in range(Nbase_x - 1):
    for i2 in range(Nbase_y_0):
        for i3 in range(Nbase_z_0):
            for j1 in range(Nbase_x_0):
                for j2 in range(Nbase_y_0):
                    for j3 in range(Nbase_z_0):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            GRAD_x[i1*Nbase_y_0*Nbase_z_0 + i2*Nbase_z_0 + i3, j1*Nbase_y_0*Nbase_z_0 + j2*Nbase_z_0 + j3] = 1
                        
                        elif i1 == j1 + 1 and i2 == j2 and i3 == j3:
                            GRAD_x[i1*Nbase_y_0*Nbase_z_0 + i2*Nbase_z_0 + i3, j1*Nbase_y_0*Nbase_z_0 + j2*Nbase_z_0 + j3] = -1
                            

                            
GRAD_y = np.zeros((Nbase_x_0*(Nbase_y - 1)*Nbase_z_0, Nbase_x_0*Nbase_y_0*Nbase_z_0))

for i1 in range(Nbase_x_0):
    for i2 in range(Nbase_y - 1):
        for i3 in range(Nbase_z_0):
            for j1 in range(Nbase_x_0):
                for j2 in range(Nbase_y_0):
                    for j3 in range(Nbase_z_0):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            GRAD_y[i1*(Nbase_y - 1)*Nbase_z_0 + i2*Nbase_z_0 + i3, j1*Nbase_y_0*Nbase_z_0 + j2*Nbase_z_0 + j3] = 1
                        
                        elif i1 == j1 and i2 == j2 + 1 and i3 == j3:
                            GRAD_y[i1*(Nbase_y - 1)*Nbase_z_0 + i2*Nbase_z_0 + i3, j1*Nbase_y_0*Nbase_z_0 + j2*Nbase_z_0 + j3] = -1

                            
                            
GRAD_z = np.zeros((Nbase_x_0*Nbase_y_0*(Nbase_z - 1), Nbase_x_0*Nbase_y_0*Nbase_z_0))

for i1 in range(Nbase_x_0):
    for i2 in range(Nbase_y_0):
        for i3 in range(Nbase_z - 1):
            for j1 in range(Nbase_x_0):
                for j2 in range(Nbase_y_0):
                    for j3 in range(Nbase_z_0):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            GRAD_z[i1*Nbase_y_0*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*Nbase_y_0*Nbase_z_0 + j2*Nbase_z_0 + j3] = 1
                        
                        elif i1 == j1 and i2 == j2 and i3 == j3 + 1:
                            GRAD_z[i1*Nbase_y_0*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*Nbase_y_0*Nbase_z_0 + j2*Nbase_z_0 + j3] = -1   
                            
                            
GRAD = np.block([[GRAD_x], [GRAD_y], [GRAD_z]])

# %%
GRAD.shape
# Out:
# (108, 27)

# %%
# assemble discrete curl matrix (V1 --> V2)
CURL_xy = np.zeros((Nbase_x_0*(Nbase_y - 1)*(Nbase_z - 1), Nbase_x_0*(Nbase_y - 1)*Nbase_z_0))

for i1 in range(Nbase_x_0):
    for i2 in range(Nbase_y - 1):
        for i3 in range(Nbase_z - 1):
            for j1 in range(Nbase_x_0):
                for j2 in range(Nbase_y - 1):
                    for j3 in range(Nbase_z_0):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            CURL_xy[i1*(Nbase_y - 1)*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*(Nbase_y - 1)*Nbase_z_0 + j2*Nbase_z_0 + j3] = -1
                        
                        elif i1 == j1 and i2 == j2 and i3 == j3 + 1:
                            CURL_xy[i1*(Nbase_y - 1)*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*(Nbase_y - 1)*Nbase_z_0 + j2*Nbase_z_0 + j3] = 1
                            

                            
                            
                            
CURL_xz = np.zeros((Nbase_x_0*(Nbase_y - 1)*(Nbase_z - 1), Nbase_x_0*Nbase_y_0*(Nbase_z - 1)))

for i1 in range(Nbase_x_0):
    for i2 in range(Nbase_y - 1):
        for i3 in range(Nbase_z - 1):
            for j1 in range(Nbase_x_0):
                for j2 in range(Nbase_y_0):
                    for j3 in range(Nbase_z - 1):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            CURL_xz[i1*(Nbase_y - 1)*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*Nbase_y_0*(Nbase_z - 1) + j2*(Nbase_z - 1) + j3] = 1
                        
                        elif i1 == j1 and i2 == j2 + 1 and i3 == j3:
                            CURL_xz[i1*(Nbase_y - 1)*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*Nbase_y_0*(Nbase_z - 1) + j2*(Nbase_z - 1) + j3] = -1
                            
                            
                            
                            
CURL_yx = np.zeros(((Nbase_x - 1)*Nbase_y_0*(Nbase_z - 1), (Nbase_x - 1)*Nbase_y_0*Nbase_z_0))

for i1 in range(Nbase_x - 1):
    for i2 in range(Nbase_y_0):
        for i3 in range(Nbase_z - 1):
            for j1 in range(Nbase_x - 1):
                for j2 in range(Nbase_y_0):
                    for j3 in range(Nbase_z_0):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            CURL_yx[i1*Nbase_y_0*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*Nbase_y_0*Nbase_z_0 + j2*Nbase_z_0 + j3] = 1
                        
                        elif i1 == j1 and i2 == j2 and i3 == j3 + 1:
                            CURL_yx[i1*Nbase_y_0*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*Nbase_y_0*Nbase_z_0 + j2*Nbase_z_0 + j3] = -1
                            
                            
                            
                            
CURL_yz = np.zeros(((Nbase_x - 1)*Nbase_y_0*(Nbase_z - 1), Nbase_x_0*Nbase_y_0*(Nbase_z - 1)))

for i1 in range(Nbase_x - 1):
    for i2 in range(Nbase_y_0):
        for i3 in range(Nbase_z - 1):
            for j1 in range(Nbase_x_0):
                for j2 in range(Nbase_y_0):
                    for j3 in range(Nbase_z - 1):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            CURL_yz[i1*Nbase_y_0*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*Nbase_y_0*(Nbase_z - 1) + j2*(Nbase_z - 1) + j3] = -1
                        
                        elif i1 == j1 + 1 and i2 == j2 and i3 == j3:
                            CURL_yz[i1*Nbase_y_0*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*Nbase_y_0*(Nbase_z - 1) + j2*(Nbase_z - 1) + j3] = 1
                            
                            
                            
                            
                            
CURL_zx = np.zeros(((Nbase_x - 1)*(Nbase_y - 1)*Nbase_z_0, (Nbase_x - 1)*Nbase_y_0*Nbase_z_0))

for i1 in range(Nbase_x - 1):
    for i2 in range(Nbase_y - 1):
        for i3 in range(Nbase_z_0):
            for j1 in range(Nbase_x - 1):
                for j2 in range(Nbase_y_0):
                    for j3 in range(Nbase_z_0):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            CURL_zx[i1*(Nbase_y - 1)*Nbase_z_0 + i2*Nbase_z_0 + i3, j1*Nbase_y_0*Nbase_z_0 + j2*Nbase_z_0 + j3] = -1
                        
                        elif i1 == j1 and i2 == j2 + 1 and i3 == j3:
                            CURL_zx[i1*(Nbase_y - 1)*Nbase_z_0 + i2*Nbase_z_0 + i3, j1*Nbase_y_0*Nbase_z_0 + j2*Nbase_z_0 + j3] = 1
                            
                            
                            
CURL_zy = np.zeros(((Nbase_x - 1)*(Nbase_y - 1)*Nbase_z_0, Nbase_x_0*(Nbase_y - 1)*Nbase_z_0))

for i1 in range(Nbase_x - 1):
    for i2 in range(Nbase_y - 1):
        for i3 in range(Nbase_z_0):
            for j1 in range(Nbase_x_0):
                for j2 in range(Nbase_y - 1):
                    for j3 in range(Nbase_z_0):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            CURL_zy[i1*(Nbase_y - 1)*Nbase_z_0 + i2*Nbase_z_0 + i3, j1*(Nbase_y - 1)*Nbase_z_0 + j2*Nbase_z_0 + j3] = 1
                        
                        elif i1 == j1 + 1 and i2 == j2 and i3 == j3:
                            CURL_zy[i1*(Nbase_y - 1)*Nbase_z_0 + i2*Nbase_z_0 + i3, j1*(Nbase_y - 1)*Nbase_z_0 + j2*Nbase_z_0 + j3] = -1
                            
                            
ZERO_xx = np.zeros((Nbase_x_0*(Nbase_y - 1)*(Nbase_z - 1), (Nbase_x - 1)*Nbase_y_0*Nbase_z_0)) 
ZERO_yy = np.zeros(((Nbase_x - 1)*Nbase_y_0*(Nbase_z - 1), Nbase_x_0*(Nbase_y - 1)*Nbase_z_0))
ZERO_zz = np.zeros(((Nbase_x - 1)*(Nbase_y - 1)*Nbase_z_0, Nbase_x_0*Nbase_y_0*(Nbase_z - 1)))


CURL = np.block([[ZERO_xx, CURL_xy, CURL_xz], [CURL_yx, ZERO_yy, CURL_yz], [CURL_zx, CURL_zy, ZERO_zz]])

# %%
CURL.shape
# Out:
# (144, 108)

# %%
# assemble discrete divergence matrix (V2 --> V3)
DIV_x = np.zeros(((Nbase_x - 1)*(Nbase_y - 1)*(Nbase_z - 1), Nbase_x_0*(Nbase_y - 1)*(Nbase_z - 1)))

for i1 in range(Nbase_x - 1):
    for i2 in range(Nbase_y - 1):
        for i3 in range(Nbase_z - 1):
            for j1 in range(Nbase_x_0):
                for j2 in range(Nbase_y - 1):
                    for j3 in range(Nbase_z - 1):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            DIV_x[i1*(Nbase_y - 1)*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*(Nbase_y - 1)*(Nbase_z - 1) + j2*(Nbase_z - 1) + j3] = 1
                        
                        elif i1 == j1 + 1 and i2 == j2 and i3 == j3:
                            DIV_x[i1*(Nbase_y - 1)*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*(Nbase_y - 1)*(Nbase_z - 1) + j2*(Nbase_z - 1) + j3] = -1
                            
                            
                            
DIV_y = np.zeros(((Nbase_x - 1)*(Nbase_y - 1)*(Nbase_z - 1), (Nbase_x - 1)*Nbase_y_0*(Nbase_z - 1)))

for i1 in range(Nbase_x - 1):
    for i2 in range(Nbase_y - 1):
        for i3 in range(Nbase_z - 1):
            for j1 in range(Nbase_x - 1):
                for j2 in range(Nbase_y_0):
                    for j3 in range(Nbase_z - 1):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            DIV_y[i1*(Nbase_y - 1)*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*Nbase_y_0*(Nbase_z - 1) + j2*(Nbase_z - 1) + j3] = 1
                        
                        elif i1 == j1 and i2 == j2 + 1 and i3 == j3:
                            DIV_y[i1*(Nbase_y - 1)*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*Nbase_y_0*(Nbase_z - 1) + j2*(Nbase_z - 1) + j3] = -1
                            
                            
                            
                            
                            
DIV_z = np.zeros(((Nbase_x - 1)*(Nbase_y - 1)*(Nbase_z - 1), (Nbase_x - 1)*(Nbase_y - 1)*Nbase_z_0))

for i1 in range(Nbase_x - 1):
    for i2 in range(Nbase_y - 1):
        for i3 in range(Nbase_z - 1):
            for j1 in range(Nbase_x - 1):
                for j2 in range(Nbase_y - 1):
                    for j3 in range(Nbase_z_0):
            
                        if i1 == j1 and i2 == j2 and i3 == j3:
                            DIV_z[i1*(Nbase_y - 1)*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*(Nbase_y - 1)*Nbase_z_0 + j2*Nbase_z_0 + j3] = 1
                        
                        elif i1 == j1 and i2 == j2 + 1 and i3 == j3:
                            DIV_z[i1*(Nbase_y - 1)*(Nbase_z - 1) + i2*(Nbase_z - 1) + i3, j1*(Nbase_y - 1)*Nbase_z_0 + j2*Nbase_z_0 + j3] = -1
                            
                            
DIV = np.block([DIV_x, DIV_y, DIV_z])

# %%
DIV.shape
# Out:
# (64, 144)

# %%
def evaluate_field_V0(vec, x, y, z):
    
    N_x = bsplines.collocation_matrix(Tx, px, x, bc).flatten()[1:Nbase_x-1]
    N_y = bsplines.collocation_matrix(Ty, py, y, bc).flatten()[1:Nbase_y-1]
    N_z = bsplines.collocation_matrix(Tz, pz, z, bc).flatten()[1:Nbase_z-1]
    
    NN = np.zeros((Nbase_x_0, Nbase_y_0, Nbase_z_0))
    for i in range(Nbase_x_0):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z_0):
                NN[i, j, k] = N_x[i]*N_y[j]*N_z[k]
                            
    NN = np.reshape(NN, Nbase_x_0*Nbase_y_0*Nbase_z_0)
    
    return np.dot(NN, vec)



def kernel_V0_static(Nbase_x_0, Nbase_y_0, Nbase_z_0, N_x, N_y, N_z, NN):
    
    for i in range(Nbase_x_0):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z_0):
                NN[i, j, k] = N_x[i]*N_y[j]*N_z[k]

                
header_V0 = '#$ header procedure kernel_V0_static(int, int, int, double [:], double [:], double [:], double [:,:,:])'


def evaluate_field_V0_kernel(vec, x, y, z, kernel_V0):
    
    N_x = bsplines.collocation_matrix(Tx, px, x, bc).flatten()[1:Nbase_x-1]
    N_y = bsplines.collocation_matrix(Ty, py, y, bc).flatten()[1:Nbase_y-1]
    N_z = bsplines.collocation_matrix(Tz, pz, z, bc).flatten()[1:Nbase_z-1]
    
    NN = np.zeros((Nbase_x_0, Nbase_y_0, Nbase_z_0), order = 'F')
    kernel_V0(Nbase_x_0, Nbase_y_0, Nbase_z_0, N_x, N_y, N_z, NN)                      
    NN = np.reshape(NN, Nbase_x_0*Nbase_y_0*Nbase_z_0)
    
    return np.dot(NN, vec)

# %%
kernel_V0 = epyccel(kernel_V0_static, header_V0)
# Out:
# def kernel_V0_static(Nbase_x_0, Nbase_y_0, Nbase_z_0, N_x, N_y, N_z, NN):
#
#     for i in range(0, Nbase_x_0):
#         for j in range(0, Nbase_y_0):
#             for k in range(0, Nbase_z_0):
#                 NN[i, j, k] = N_x[i]*N_y[j]*N_z[k]

# %%
def evaluate_field_V1_x(vec, x, y, z):
    
    N_y = bsplines.collocation_matrix(Ty, py, y, bc).flatten()[1:Nbase_y-1]
    N_z = bsplines.collocation_matrix(Tz, pz, z, bc).flatten()[1:Nbase_z-1]
    
    NN = np.zeros(((Nbase_x - 1), Nbase_y_0, Nbase_z_0))
    for i in range(Nbase_x - 1):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z_0):
                NN[i, j, k] = px*Dx(x, i + 1)/(Tx[i + 1 + px] - Tx[i + 1])*N_y[j]*N_z[k]
                
    NN = np.reshape(NN, (Nbase_x - 1)*Nbase_y_0*Nbase_z_0)
    
    return np.dot(NN, vec)


def evaluate_field_V1_y(vec, x, y, z):
    
    N_x = bsplines.collocation_matrix(Tx, px, x, bc).flatten()[1:Nbase_x-1]
    N_z = bsplines.collocation_matrix(Tz, pz, z, bc).flatten()[1:Nbase_z-1]
    
    NN = np.zeros((Nbase_x_0, (Nbase_y - 1), Nbase_z_0))
    for i in range(Nbase_x_0):
        for j in range(Nbase_y - 1):
            for k in range(Nbase_z_0):
                NN[i, j, k] = N_x[i]*py*Dy(y, j + 1)/(Ty[j + 1 + py] - Ty[j + 1])*N_z[k]
                
    NN = np.reshape(NN, Nbase_x_0*(Nbase_y - 1)*Nbase_z_0)
    
    return np.dot(NN, vec)


def evaluate_field_V1_z(vec, x, y, z):
    
    N_x = bsplines.collocation_matrix(Tx, px, x, bc).flatten()[1:Nbase_x-1]
    N_y = bsplines.collocation_matrix(Ty, py, y, bc).flatten()[1:Nbase_y-1]
    
    NN = np.zeros((Nbase_x_0, Nbase_y_0, (Nbase_z - 1)))
    for i in range(Nbase_x_0):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z - 1):
                NN[i, j, k] = N_x[i]*N_y[j]*pz*Dz(z, k + 1)/(Tz[k + 1 + pz] - Tz[k + 1])
                
    NN = np.reshape(NN, Nbase_x_0*Nbase_y_0*(Nbase_z - 1))
    
    return np.dot(NN, vec)

# %%
def evaluate_field_V2_x(vec, x, y, z):
    
    N_x = bsplines.collocation_matrix(Tx, px, x, bc).flatten()[1:Nbase_x-1]
    
    NN = np.zeros((Nbase_x_0, (Nbase_y - 1), (Nbase_z - 1)))
    for i in range(Nbase_x_0):
        for j in range(Nbase_y - 1):
            for k in range(Nbase_z - 1):
                NN[i, j, k] = N_x[i]*py*Dy(y, j + 1)/(Ty[j + 1 + py] - Ty[j + 1])*pz*Dz(z, k + 1)/(Tz[k + 1 + pz] - Tz[k + 1])
                
    NN = np.reshape(NN, Nbase_x_0*(Nbase_y - 1)*(Nbase_z - 1))
    
    return np.dot(NN, vec)


def evaluate_field_V2_y(vec, x, y, z):
    
    N_y = bsplines.collocation_matrix(Ty, py, y, bc).flatten()[1:Nbase_y-1]
    
    NN = np.zeros(((Nbase_x - 1), Nbase_y_0, (Nbase_z - 1)))
    for i in range(Nbase_x - 1):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z - 1):
                NN[i, j, k] = px*Dx(x, i + 1)/(Tx[i + 1 + px] - Tx[i + 1])*N_y[j]*pz*Dz(z, k + 1)/(Tz[k + 1 + pz] - Tz[k + 1])
                
    NN = np.reshape(NN, (Nbase_x - 1)*Nbase_y_0*(Nbase_z - 1))
    
    return np.dot(NN, vec)


def evaluate_field_V2_z(vec, x, y, z):
    
    N_z = bsplines.collocation_matrix(Tz, pz, z, bc).flatten()[1:Nbase_z-1]
    
    NN = np.zeros(((Nbase_x - 1), (Nbase_y - 1), Nbase_z_0))
    for i in range(Nbase_x - 1):
        for j in range(Nbase_y - 1):
            for k in range(Nbase_z_0):
                NN[i, j, k] = px*Dx(x, i + 1)/(Tx[i + 1 + px] - Tx[i + 1])*py*Dy(y, j + 1)/(Ty[j + 1 + py] - Ty[j + 1])*N_z[k]
                
    NN = np.reshape(NN, (Nbase_x - 1)*(Nbase_y - 1)*Nbase_z_0)
    
    return np.dot(NN, vec)

# %%
def evaluate_field_V3(vec, x, y, z):
    
    NN = np.zeros(((Nbase_x - 1), (Nbase_y - 1), (Nbase_z - 1)))
    for i in range(Nbase_x - 1):
        for j in range(Nbase_y - 1):
            for k in range(Nbase_z - 1):
                NN[i, j, k] = px*Dx(x, i + 1)/(Tx[i + 1 + px] - Tx[i + 1])*py*Dy(y, j + 1)/(Ty[j + 1 + py] - Ty[j + 1])*pz*Dz(z, k + 1)/(Tz[k + 1 + pz] - Tz[k + 1])
                
    NN = np.reshape(NN, (Nbase_x - 1)*(Nbase_y - 1)*(Nbase_z - 1))
    
    return np.dot(NN, vec)

# %%
def PI_0(fun):

    # assemble vector of evaluated function at greville points
    vec_psi_xi = np.zeros((Nbase_x_0, Nbase_y_0, Nbase_z_0))

    for i in range(Nbase_x_0):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z_0):
                vec_psi_xi[i, j, k] = fun(greville_x_0[i], greville_y_0[j], greville_z_0[k])

    vec_psi_xi = np.reshape(vec_psi_xi, Nbase_x_0*Nbase_y_0*Nbase_z_0)            



    # assemble interpolation matrix
    K = np.zeros((Nbase_x_0, Nbase_y_0, Nbase_z_0, Nbase_x_0, Nbase_y_0, Nbase_z_0))

    for i in range(Nbase_x_0):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z_0):
                for l in range(Nbase_x_0):
                    for m in range(Nbase_y_0):
                        for n in range(Nbase_z_0):
                            K[i, j, k, l, m, n] = col_x_0[l, i]*col_y_0[m, j]*col_z_0[n, k]

    K = np.reshape(K, (Nbase_x_0*Nbase_y_0*Nbase_z_0, Nbase_x_0*Nbase_y_0*Nbase_z_0))

    # solve interpolation problem
    vec_fun = np.linalg.solve(K, vec_psi_xi)
    
    return vec_fun


def kernel_PI_0_static(Nbase_x_0, Nbase_y_0, Nbase_z_0, col_x_0, col_y_0, col_z_0, K):
    
    for i in range(Nbase_x_0):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z_0):
                for l in range(Nbase_x_0):
                    for m in range(Nbase_y_0):
                        for n in range(Nbase_z_0):
                            K[i, j, k, l, m, n] = col_x_0[l, i]*col_y_0[m, j]*col_z_0[n, k]
                            

header_PI_0 = '#$ header procedure kernel_PI_0_static(int, int, int, double [:,:], double [:,:], double [:,:], double [:,:,:,:,:,:])'
                            
def PI_0_kernel(fun, kernel_PI_0):

    # assemble vector of evaluated function at greville points
    vec_psi_xi = np.zeros((Nbase_x_0, Nbase_y_0, Nbase_z_0))

    for i in range(Nbase_x_0):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z_0):
                vec_psi_xi[i, j, k] = fun(greville_x_0[i], greville_y_0[j], greville_z_0[k])

    vec_psi_xi = np.reshape(vec_psi_xi, Nbase_x_0*Nbase_y_0*Nbase_z_0)            



    # assemble interpolation matrix
    K = np.zeros((Nbase_x_0, Nbase_y_0, Nbase_z_0, Nbase_x_0, Nbase_y_0, Nbase_z_0), order = 'F')
    kernel_PI_0(Nbase_x_0, Nbase_y_0, Nbase_z_0, col_x_0, col_y_0, col_z_0, K)
    K = np.reshape(K, (Nbase_x_0*Nbase_y_0*Nbase_z_0, Nbase_x_0*Nbase_y_0*Nbase_z_0))

    # solve interpolation problem
    vec_fun = np.linalg.solve(K, vec_psi_xi)
    
    return vec_fun

# %%
def PI_1_x(fun):

    # assemble vector of interpolation-histopolation problem at greville points
    vec_psi_xi = np.zeros((Nbase_x - 1, Nbase_y_0, Nbase_z_0))

    for i in range(Nbase_x - 1):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z_0):
                
                integrand = lambda x : fun(x, greville_y_0[j], greville_z_0[k])

                vec_psi_xi[i, j, k] = fixed_quad(integrand, greville_x[i], greville_x[i + 1])[0]

    vec_psi_xi = np.reshape(vec_psi_xi, (Nbase_x - 1)*Nbase_y_0*Nbase_z_0) 
    
    
    # assemble interpolation-histopolation matrix
    K = np.zeros((Nbase_x - 1, Nbase_y_0, Nbase_z_0, Nbase_x - 1, Nbase_y_0, Nbase_z_0))

    for i in range(Nbase_x - 1):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z_0):
                for l in range(Nbase_x - 1):
                    for m in range(Nbase_y_0):
                        for n in range(Nbase_z_0):
                            
                            integrand = lambda x : px*Dx(x, l + 1)/(Tx[l + 1 + px] - Tx[l + 1])*col_y_0[m, j]*col_z_0[n, k] 
                            
                            K[i, j, k, l, m, n] = fixed_quad(integrand, greville_x[i], greville_x[i + 1])[0]

    K = np.reshape(K, ((Nbase_x - 1)*Nbase_y_0*Nbase_z_0, (Nbase_x - 1)*Nbase_y_0*Nbase_z_0))
    
    # solve interpolation-histopolation problem
    vec_fun = np.linalg.solve(K, vec_psi_xi)
    
    return vec_fun



def PI_1_y(fun):

    # assemble vector of interpolation-histopolation problem at greville points
    vec_psi_xi = np.zeros((Nbase_x_0, Nbase_y - 1, Nbase_z_0))

    for i in range(Nbase_x_0):
        for j in range(Nbase_y - 1):
            for k in range(Nbase_z_0):
                
                integrand = lambda y : fun(greville_x_0[i], y, greville_z_0[k])

                vec_psi_xi[i, j, k] = fixed_quad(integrand, greville_y[j], greville_y[j + 1])[0]

    vec_psi_xi = np.reshape(vec_psi_xi, Nbase_x_0*(Nbase_y - 1)*Nbase_z_0) 
    
    
    # assemble interpolation-histopolation matrix
    K = np.zeros((Nbase_x_0, Nbase_y - 1, Nbase_z_0, Nbase_x_0, Nbase_y - 1, Nbase_z_0))

    for i in range(Nbase_x_0):
        for j in range(Nbase_y - 1):
            for k in range(Nbase_z_0):
                for l in range(Nbase_x_0):
                    for m in range(Nbase_y - 1):
                        for n in range(Nbase_z_0):
                            
                            integrand = lambda y : col_x_0[l, i]*py*Dy(y, m + 1)/(Ty[m + 1 + py] - Ty[m + 1])*col_z_0[n, k] 
                            
                            K[i, j, k, l, m, n] = fixed_quad(integrand, greville_y[j], greville_y[j + 1])[0]

    K = np.reshape(K, (Nbase_x_0*(Nbase_y - 1)*Nbase_z_0, Nbase_x_0*(Nbase_y - 1)*Nbase_z_0))
    
    # solve interpolation-histopolation problem
    vec_fun = np.linalg.solve(K, vec_psi_xi)
    
    return vec_fun


def PI_1_z(fun):

    # assemble vector of interpolation-histopolation problem at greville points
    vec_psi_xi = np.zeros((Nbase_x_0, Nbase_y_0, Nbase_z - 1))

    for i in range(Nbase_x_0):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z - 1):
                
                integrand = lambda z : fun(greville_x_0[i], greville_y_0[j], z)

                vec_psi_xi[i, j, k] = fixed_quad(integrand, greville_z[k], greville_z[k + 1])[0]

    vec_psi_xi = np.reshape(vec_psi_xi, Nbase_x_0*Nbase_y_0*(Nbase_z - 1)) 
    
    
    # assemble interpolation-histopolation matrix
    K = np.zeros((Nbase_x_0, Nbase_y_0, Nbase_z - 1, Nbase_x_0, Nbase_y_0, Nbase_z - 1))

    for i in range(Nbase_x_0):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z - 1):
                for l in range(Nbase_x_0):
                    for m in range(Nbase_y_0):
                        for n in range(Nbase_z - 1):
                            
                            integrand = lambda z : col_x_0[l, i]*col_y_0[m, j]*pz*Dz(z, n + 1)/(Tz[n + 1 + pz] - Tz[n + 1]) 
                            
                            K[i, j, k, l, m, n] = fixed_quad(integrand, greville_z[k], greville_z[k + 1])[0]

    K = np.reshape(K, (Nbase_x_0*Nbase_y_0*(Nbase_z - 1), Nbase_x_0*Nbase_y_0*(Nbase_z - 1)))
    
    # solve interpolation-histopolation problem
    vec_fun = np.linalg.solve(K, vec_psi_xi)
    
    return vec_fun

# %%
def PI_2_x(fun):

    # assemble vector of interpolation-histopolation problem at greville points
    vec_psi_xi = np.zeros((Nbase_x_0, Nbase_y - 1, Nbase_z - 1))

    for i in range(Nbase_x_0):
        for j in range(Nbase_y - 1):
            for k in range(Nbase_z - 1):
                
                integrand = lambda y, z : fun(greville_x_0[i], y, z)

                vec_psi_xi[i, j, k] = nquad(integrand, [[greville_y[j], greville_y[j + 1]], [greville_z[k], greville_z[k + 1]]])[0]

    vec_psi_xi = np.reshape(vec_psi_xi, Nbase_x_0*(Nbase_y - 1)*(Nbase_z - 1)) 
    
    # assemble interpolation-histopolation matrix
    K = np.zeros((Nbase_x_0, Nbase_y - 1, Nbase_z - 1, Nbase_x_0, Nbase_y - 1, Nbase_z - 1))

    for i in range(Nbase_x_0):
        for j in range(Nbase_y - 1):
            for k in range(Nbase_z - 1):
                for l in range(Nbase_x_0):
                    for m in range(Nbase_y - 1):
                        for n in range(Nbase_z - 1):
                            
                            integrand = lambda y, z : col_x_0[l, i]*py*Dy(y, m + 1)/(Ty[m + 1 + py] - Ty[m + 1])*pz*Dz(z, n + 1)/(Tz[n + 1 + pz] - Tz[n + 1]) 
                            
                            K[i, j, k, l, m, n] = nquad(integrand, [[greville_y[j], greville_y[j + 1]], [greville_z[k], greville_z[k + 1]]])[0]

    K = np.reshape(K, (Nbase_x_0*(Nbase_y - 1)*(Nbase_z - 1), Nbase_x_0*(Nbase_y - 1)*(Nbase_z - 1)))
    
    # solve interpolation-histopolation problem
    vec_fun = np.linalg.solve(K, vec_psi_xi)
    
    return vec_fun


def PI_2_y(fun):

    # assemble vector of interpolation-histopolation problem at greville points
    vec_psi_xi = np.zeros((Nbase_x - 1, Nbase_y_0, Nbase_z - 1))

    for i in range(Nbase_x - 1):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z - 1):
                
                integrand = lambda x, z : fun(x, greville_y_0[j], z)

                vec_psi_xi[i, j, k] = nquad(integrand, [[greville_x[i], greville_x[i + 1]], [greville_z[k], greville_z[k + 1]]])[0]

    vec_psi_xi = np.reshape(vec_psi_xi, (Nbase_x - 1)*Nbase_y_0*(Nbase_z - 1)) 
    
    # assemble interpolation-histopolation matrix
    K = np.zeros((Nbase_x - 1, Nbase_y_0, Nbase_z - 1, Nbase_x - 1, Nbase_y_0, Nbase_z - 1))

    for i in range(Nbase_x - 1):
        for j in range(Nbase_y_0):
            for k in range(Nbase_z - 1):
                for l in range(Nbase_x - 1):
                    for m in range(Nbase_y_0):
                        for n in range(Nbase_z - 1):
                            
                            integrand = lambda x, z : px*Dx(x, l + 1)/(Tx[l + 1 + px] - Tx[l + 1])*col_y_0[m, j]*pz*Dz(z, n + 1)/(Tz[n + 1 + pz] - Tz[n + 1]) 
                            
                            K[i, j, k, l, m, n] = nquad(integrand, [[greville_x[i], greville_x[i + 1]], [greville_z[k], greville_z[k + 1]]])[0]

    K = np.reshape(K, ((Nbase_x - 1)*Nbase_y_0*(Nbase_z - 1), (Nbase_x - 1)*Nbase_y_0*(Nbase_z - 1)))
    
    # solve interpolation-histopolation problem
    vec_fun = np.linalg.solve(K, vec_psi_xi)
    
    return vec_fun


def PI_2_z(fun):

    # assemble vector of interpolation-histopolation problem at greville points
    vec_psi_xi = np.zeros((Nbase_x - 1, Nbase_y - 1, Nbase_z_0))

    for i in range(Nbase_x - 1):
        for j in range(Nbase_y - 1):
            for k in range(Nbase_z_0):
                
                integrand = lambda x, y : fun(x, y, greville_z_0[k])

                vec_psi_xi[i, j, k] = nquad(integrand, [[greville_x[i], greville_x[i + 1]], [greville_y[j], greville_y[j + 1]]])[0]

    vec_psi_xi = np.reshape(vec_psi_xi, (Nbase_x - 1)*(Nbase_y - 1)*Nbase_z_0) 
    
    # assemble interpolation-histopolation matrix
    K = np.zeros((Nbase_x - 1, Nbase_y - 1, Nbase_z_0, Nbase_x - 1, Nbase_y - 1, Nbase_z_0))

    for i in range(Nbase_x - 1):
        for j in range(Nbase_y - 1 ):
            for k in range(Nbase_z_0):
                for l in range(Nbase_x - 1):
                    for m in range(Nbase_y - 1):
                        for n in range(Nbase_z_0):
                            
                            integrand = lambda x, y : px*Dx(x, l + 1)/(Tx[l + 1 + px] - Tx[l + 1])*py*Dy(y, m + 1)/(Ty[m + 1 + py] - Ty[m + 1])*col_z_0[n, k] 
                            
                            K[i, j, k, l, m, n] = nquad(integrand, [[greville_x[i], greville_x[i + 1]], [greville_y[j], greville_y[j + 1]]])[0]

    K = np.reshape(K, ((Nbase_x - 1)*(Nbase_y - 1)*Nbase_z_0, (Nbase_x - 1)*(Nbase_y - 1)*Nbase_z_0))
    
    # solve interpolation-histopolation problem
    vec_fun = np.linalg.solve(K, vec_psi_xi)
    
    return vec_fun

# %%
def PI_3(fun):

    # assemble vector of interpolation-histopolation problem at greville points
    vec_psi_xi = np.zeros((Nbase_x - 1, Nbase_y - 1, Nbase_z - 1))

    for i in range(Nbase_x - 1):
        for j in range(Nbase_y - 1):
            for k in range(Nbase_z - 1):

                vec_psi_xi[i, j, k] = nquad(fun, [[greville_x[i], greville_x[i + 1]], [greville_y[j], greville_y[j + 1]], [greville_z[k], greville_z[k + 1]]])[0]

    vec_psi_xi = np.reshape(vec_psi_xi, (Nbase_x - 1)*(Nbase_y - 1)*(Nbase_z - 1)) 
    
    # assemble interpolation-histopolation matrix
    K = np.zeros((Nbase_x - 1, Nbase_y - 1, Nbase_z - 1, Nbase_x - 1, Nbase_y - 1, Nbase_z - 1))

    for i in range(Nbase_x - 1):
        for j in range(Nbase_y - 1 ):
            for k in range(Nbase_z - 1):
                for l in range(Nbase_x - 1):
                    for m in range(Nbase_y - 1):
                        for n in range(Nbase_z - 1):
                            
                            integrand = lambda x, y, z : px*Dx(x, l + 1)/(Tx[l + 1 + px] - Tx[l + 1])*py*Dy(y, m + 1)/(Ty[m + 1 + py] - Ty[m + 1])*pz*Dz(z, n + 1)/(Tz[n + 1 + pz] - Tz[n + 1])
                            
                            K[i, j, k, l, m, n] = nquad(integrand, [[greville_x[i], greville_x[i + 1]], [greville_y[j], greville_y[j + 1]], [greville_z[k], greville_z[k + 1]]])[0]

    K = np.reshape(K, ((Nbase_x - 1)*(Nbase_y - 1)*(Nbase_z - 1), (Nbase_x - 1)*(Nbase_y - 1)*(Nbase_z - 1)))
    
    # solve interpolation-histopolation problem
    vec_fun = np.linalg.solve(K, vec_psi_xi)
    
    return vec_fun

# %%
# test 1
Psi = lambda x, y, z : x*(1 - x)*y*(1 - y)*z*(1 - z)

grad_Psi_x = lambda x, y, z: (1 - 2*x)*y*(1 - y)*z*(1 - z)
grad_Psi_y = lambda x, y, z: (1 - 2*y)*x*(1 - x)*z*(1 - z)
grad_Psi_z = lambda x, y, z: (1 - 2*z)*x*(1 - x)*y*(1 - y)



'''
# test 2
Psi = lambda x, y, z : np.sin(4*x)*(1 - x)*np.sin(4*y)*(1 - y)*np.sin(4*z)*(1 - z)

grad_Psi_x = lambda x, y, z: (4*np.cos(4*x) - np.sin(4*x))*np.sin(4*y)*(1 - y)*np.sin(4*z)*(1 - z)
grad_Psi_y = lambda x, y, z: (4*np.cos(4*y) - np.sin(4*y))*np.sin(4*x)*(1 - x)*np.sin(4*z)*(1 - z)
grad_Psi_z = lambda x, y, z: (4*np.cos(4*z) - np.sin(4*z))*np.sin(4*x)*(1 - x)*np.sin(4*y)*(1 - y)
'''

x_test = np.array([0.33])
y_test = np.array([0.5])
z_test = np.array([0.15])

print('Projector 0')
print(Psi(x_test, y_test, z_test)[0])
print(evaluate_field_V0(PI_0(Psi), x_test, y_test, z_test))

print('----------------------------')
print('Projector 1')
print(Psi(x_test, y_test, z_test)[0])
print(evaluate_field_V1_x(PI_1_x(Psi), x_test, y_test, z_test))
# Out:
# Projector 0
# 0.0070475625
# 0.0070475625
# ----------------------------
# Projector 1
# 0.0070475625
# 0.007545593390734191

# %%
# measure elapsed time
test_vec = PI_0(Psi)

timea = time.time()
res1 = evaluate_field_V0(test_vec, x_test, y_test, z_test)
timeb = time.time()
diff1 = timeb - timea
print('Pure python : ' + str(diff1))

timea = time.time()
res2 = evaluate_field_V0_kernel(test_vec, x_test, y_test, z_test, kernel_V0)
timeb = time.time()
diff2 = timeb - timea
print('Pyccel : ' + str(diff2))

print('Acceleration : ' + str(diff1/diff2))
# Out:
# Pure python : 0.002935647964477539
# Pyccel : 0.0003361701965332031
# Acceleration : 8.732624113475177

# %%
# check commuting diagram property
vec_0 = np.dot(GRAD, PI_0(Psi))

vec_1_x = PI_1_x(grad_Psi_x)
vec_1_y = PI_1_y(grad_Psi_y)
vec_1_z = PI_1_z(grad_Psi_z)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib qt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.linspace(0, Lx, 40)
Z = np.linspace(0, Lz, 40)
X, Z = np.meshgrid(X, Z)

PSI = Psi(X, 0.5, Z)

# Plot the surface.
surf = ax.plot_surface(X, Z, PSI, cmap=cm.coolwarm, linewidth=0, antialiased=False)
ax.set_xlabel('x')
ax.set_ylabel('z')

# Customize the z axis.
#ax.set_zlim(-1.01, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
#ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)
# Out:
# Text(0.5,0,'z')

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib qt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
xplot = np.linspace(0, Lx, 40)
zplot = np.linspace(0, Lz, 40)
X, Z = np.meshgrid(xplot, zplot)

PSI = np.zeros((40, 40))

vec = PI_0(Psi)

for i in range(40):
    for j in range(40):
        PSI[i, j] = evaluate_field_V0(vec, np.array([xplot[i]]), np.array([0.5]), np.array([zplot[j]]))

# Plot the surface.
surf = ax.plot_surface(X, Z, PSI, cmap=cm.coolwarm, linewidth=0, antialiased=False)
ax.set_xlabel('x')
ax.set_ylabel('z')

# Customize the z axis.
#ax.set_zlim(-1.01, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
#ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)
# Out:
# Text(0.5,0,'z')

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
# %matplotlib qt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
xplot = np.linspace(0, Lx, 40)
zplot = np.linspace(0, Lz, 40)
X, Z = np.meshgrid(xplot, zplot)

PSI = np.zeros((40, 40))

vec = PI_1_x(Psi)

for i in range(40):
    for j in range(40):
        PSI[i, j] = evaluate_field_V1_x(vec, np.array([xplot[i]]), np.array([0.5]), np.array([zplot[j]]))

# Plot the surface.
surf = ax.plot_surface(X, Z, PSI, cmap=cm.coolwarm, linewidth=0, antialiased=False)
ax.set_xlabel('x')
ax.set_ylabel('z')

# Customize the z axis.
#ax.set_zlim(-1.01, 1.01)
#ax.zaxis.set_major_locator(LinearLocator(10))
#ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
#fig.colorbar(surf, shrink=0.5, aspect=5)
# Out:
# Text(0.5,0,'z')

# %%
test
# Out:
# 0.779508594310854

# %%
Ds = bsplines.basis_funs(Tx_D, px-1, 0.2/3, 1)
div = 1/dx*(Ds[0] - Ds[1])
div
# Out:
# 1.6666666666666672

# %%
Ds = bsplines.basis_funs(Tx, px, 0.2/3, 2)
div = Ds[1] - Ds[0]
Ds
# Out:
# array([0.22222222, 0.72222222, 0.05555556])

# %%
bsplines.basis_funs_1st_der(Tx, px, 0.2/3, 2)
# Out:
# array([-3.33333333,  1.66666667,  1.66666667])

# %%
bsplines.basis_funs(Tx_D, px-1, 0.2/3, 1)
# Out:
# array([0.66666667, 0.33333333])

# %%
Psi(0,0,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-316c28fac49a> in <module>()
# ----> 1 Psi(0,0,0)
#
# <ipython-input-25-c92c7a141ad4> in Psi(x, y, z)
#       4
#       5 def Psi(x, y, z):
# ----> 6     return np*sin(kx*x)*np.cos(ky*y)*np.sin(kz*z)
#       7
#       8
#
# NameError: name 'sin' is not defined

# %%
Tx
# Out:
# array([0. , 0. , 0. , 0.2, 0.4, 0.6, 0.8, 1. , 1. , 1. ])

# %%
Lz = 1.
p2 = 2
Nel = 3

el_b = np.linspace(0, Lz, Nel + 1)
T = np.array([0]*p2 + list(el_b) + [Lz]*p2)

bsp_2 = utils.Bspline(T, p2)


zplot = np.linspace(0, Lz, 200)

for j in range(bsp_2.N):
    plt.plot(zplot, bsp_2(zplot, j))

# %%
T
# Out:
# array([0.   , 0.   , 0.   , 0.125, 0.25 , 0.375, 0.5  , 0.625, 0.75 ,
#        0.875, 1.   , 1.   , 1.   ])

# %%
Lz = 1.
p1 = 1
Nel = 8

el_b = np.linspace(0, Lz, Nel + 1)
bsp_1 = utils.Bspline(T, p1)


zplot = np.linspace(0, Lz, 400)

for j in range(bsp_1.N):
    plt.plot(zplot, bsp_1(zplot, j))

plt.plot(greville_x, np.zeros(len(greville_x)), 'k+')

# %%
fun = lambda x : bsp_1(x, 9)
fixed_quad(fun, greville_x[8], greville_x[9])[0]
# Out:
# 0.046875

# %%
for j in range(bsp_2.N):
    plt.plot(zplot, bsp_2(zplot, j, 1))
