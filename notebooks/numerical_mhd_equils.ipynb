# %%
from struphy.fields_background.mhd_equil.equils import EQDSKequilibriumWithDomain, GVECequilibrium

# %%
mhd_equil = EQDSKequilibriumWithDomain(show=True)
mhd_equil.show()

# %%
# choose which equilibrium to plot
mhd_equil = GVECequilibrium()
mhd_equil.show() # vtk files are generated in this step too
