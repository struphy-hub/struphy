# %%
from struphy.geometry import domains

# %%
domain = domains.Cuboid()
domain.show()

# %%
domain = domains.Orthogonal()
domain.show()

# %%
domain = domains.Colella()
domain.show()

# %%
domain = domains.HollowCylinder()
domain.show()

# %%
domain = domains.PoweredEllipticCylinder()
domain.show()

# %%
domain = domains.HollowTorus()
domain.show()

# %%
domain = domains.ShafranovShiftCylinder()
domain.show()

# %%
domain = domains.ShafranovSqrtCylinder()
domain.show()

# %%
domain = domains.ShafranovDshapedCylinder()
domain.show()

# %%
domain = domains.Tokamak()
domain.show()

# %%
domain = domains.GVECunit()
domain.show()

# %%
domain = domains.IGAPolarCylinder()
domain.show()

# %%
domain = domains.IGAPolarTorus()
domain.show()
