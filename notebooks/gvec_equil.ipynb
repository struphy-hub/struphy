# %%
from struphy.fields_background.mhd_equil.numerical import GVECequilibrium

# %%
# choose which equilibrium to plot
mhd_equil = GVECequilibrium()
mhd_equil.plot_equil() # vtk files are generated in this step too
