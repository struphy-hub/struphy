# %%
from struphy.pic.pushing.test import fun, A

# %%
import numpy as np
n = 10
out = np.zeros((n, n), dtype=float)
fun(n, out)

# %%
a = A(3)
b = A(4)

# %%
a._n

# %%
a.n()

# %%
a.return_n()

# %%
b.n()
