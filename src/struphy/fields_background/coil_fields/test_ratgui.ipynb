# %%
from struphy.fields_background.coil_fields.coil_fields import RatGUI
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from struphy.fields_background.coil_fields.coil_fields import RatGUI
#
# File ~/git_repos/struphy/src/struphy/fields_background/coil_fields/coil_fields.py:1
# ----> 1 from struphy.fields_background.coil_fields import CoilMagneticField
#       3 class RatGUI(CoilMagneticField):
#       4     '''Interface to RatGUI.'''
#
# ImportError: cannot import name 'CoilMagneticField' from 'struphy.fields_background.coil_fields' (/home/spossann/git_repos/struphy/src/struphy/fields_background/coil_fields/__init__.py)

# %%
ratgui = RatGUI()

# %%
ratgui._a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 cf._a
#
# AttributeError: 'CoilMagneticField' object has no attribute '_a'
